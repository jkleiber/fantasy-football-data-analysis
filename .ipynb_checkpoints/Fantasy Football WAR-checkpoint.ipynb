# %% [markdown]
# # Setup

# %%
# import packages
import pandas as pd
import plotly.graph_objects as go
import nfl_data_py as nfl  # load data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Utility Functions

# %%
# Get normal distribution parameters for a player
def player_dist(weekly_df, player_name):
    # Get each week's data
    player_weeks_df = weekly_df[weekly_df['player_display_name'] == player_name]
    
    # Number of games played by the player.
    n_games = len(player_weeks_df.index)
    
    # Convert to numpy
    player_weeks_np = player_weeks_df[['fantasy_points_ppr']].to_numpy()
        
    # Average and variance
    avg = np.average(player_weeks_np)
    s2 = np.var(player_weeks_np)
    
    return avg, s2, n_games

def sample_ppr_repl_team(position_replacements, lineup, N):
    n_lineup_spots = len(lineup)
    
    # Sample scores
    ppr_team_scores = None
    for i in range(n_lineup_spots):
        # Get the position from the lineup
        pos = lineup[i]

        # Get position distribution parameters
        mean = position_replacements[pos]['avg']
        std = np.sqrt(position_replacements[pos]['s2'])

        # Sample the position
        pos_samples = np.random.default_rng().normal(mean, std, N)

        # Add to the scores
        if ppr_team_scores is None:
            ppr_team_scores = pos_samples
        else:
            ppr_team_scores += pos_samples
    
    return ppr_team_scores

def sample_player(weekly_df, player_name, N):
    # Get player distribution
    mu, s2, n_games = player_dist(weekly_df, player_name)
        
    # Convert s2 to std. dev
    std = np.sqrt(s2)
    player_samples = np.random.default_rng().normal(mu, std, N)
    
    # Ensure player scores are >= 0
    player_samples[player_samples < 0] = 0.0
    
    return player_samples

# %%
def plot_samples(scores, mu, sigma):
    count, bins, ignored = plt.hist(scores, 30, density=True)
    plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=2, color='r')

    plt.show()

# %% [markdown]
# # Kickers

# %%
kicker_df = nfl.import_pbp_data([2022], ['week', 'play_type', 'kicker_player_name', 'kicker_player_id', 'field_goal_attempt', 'field_goal_result', 'kick_distance', 'extra_point_attempt', 'extra_point_result', 'fantasy_player_name'], downcast=True, cache=False, alt_path=None)
# Out:
# 2022 done.
# Downcasting floats.

# %%
kicker_df = kicker_df[kicker_df['week'] <= 17]

# %%
fg_df = kicker_df[kicker_df['field_goal_attempt'] == True]
pat_df = kicker_df[kicker_df['extra_point_attempt'] == True]
kicker_names_df = kicker_df['kicker_player_name'].unique()

# %%
kicker_names = list(kicker_names_df)

# %%
fg_df
# Out:
#        week   play_type kicker_player_name kicker_player_id  \
# 32        1  field_goal           J.Tucker       00-0029597
# 51        1  field_goal         G.Zuerlein       00-0029621
# 82        1  field_goal         G.Zuerlein       00-0029621
# 226       1  field_goal             T.Bass       00-0036162
# 259       1  field_goal              M.Gay       00-0035269
# ...     ...         ...                ...              ...
# 45013    17  field_goal            R.Gould       00-0023252
# 45029    17  field_goal            R.Gould       00-0023252
# 45038    17  field_goal          D.Carlson       00-0034161
# 45064    17  field_goal            R.Gould       00-0023252
# 45072    17  field_goal            R.Gould       00-0023252
#
#        field_goal_attempt field_goal_result  kick_distance  \
# 32                    1.0              made           24.0
# 51                    1.0            missed           45.0
# 82                    1.0              made           45.0
# 226                   1.0              made           41.0
# 259                   1.0              made           57.0
# ...                   ...               ...            ...
# 45013                 1.0              made           43.0
# 45029                 1.0              made           24.0
# 45038                 1.0              made           57.0
# 45064                 1.0            missed           41.0
# 45072                 1.0              made           23.0
#
#        extra_point_attempt extra_point_result fantasy_player_name  ...  \
# 32                     0.0               None                None  ...
# 51                     0.0               None                None  ...
# 82                     0.0               None                None  ...
# 226                    0.0               None                None  ...
# 259                    0.0               None                None  ...
# ...                    ...                ...                 ...  ...
# 45013                  0.0               None                None  ...
# 45029                  0.0               None                None  ...
# 45038                  0.0               None                None  ...
# 45064                  0.0               None                None  ...
# 45072                  0.0               None                None  ...
#
#        offense_formation offense_personnel  defenders_in_box  \
# 32                  None              None               NaN
# 51                  None              None               NaN
# 82                  None              None               NaN
# 226                 None              None               NaN
# 259                 None              None               NaN
# ...                  ...               ...               ...
# 45013               None              None               NaN
# 45029               None              None               NaN
# 45038               None              None               NaN
# 45064               None              None               NaN
# 45072               None              None               NaN
#
#       defense_personnel number_of_pass_rushers  \
# 32                 None                    NaN
# 51                 None                    NaN
# 82                 None                    NaN
# 226                None                    NaN
# 259                None                    NaN
# ...                 ...                    ...
# 45013              None                    NaN
# 45029              None                    NaN
# 45038              None                    NaN
# 45064              None                    NaN
# 45072              None                    NaN
#
#                                          players_on_play  \
# 32     47906;52578;54595;54469;53575;46186;47786;3313...
# 51     52578;43586;42371;53059;53443;42500;44999;3313...
# 82     43586;52578;42371;53059;53443;42500;44999;3313...
# 226    48512;52512;43617;52835;39684;43335;42569;4487...
# 259    42400;48226;48482;52835;46085;40166;52647;4788...
# ...                                                  ...
# 45013  43616;55105;47811;44387;30403;53508;48581;4621...
# 45029  43616;55105;44387;47811;30403;53508;48581;4621...
# 45038  53601;46084;47944;53609;44972;46349;46157;4241...
# 45064  43616;55105;47811;44387;30403;53508;48581;4621...
# 45072  43616;55105;47811;44387;30403;53508;48581;4621...
#
#                                          offense_players  \
# 32     00-0034978;00-0036081;00-0038094;00-0026190;00...
# 51     00-0032466;00-0032234;00-0036979;00-0032134;00...
# 82     00-0032466;00-0032234;00-0036979;00-0032134;00...
# 226    00-0035382;00-0032497;00-0029685;00-0031622;00...
# 259    00-0032242;00-0035118;00-0035933;00-0035666;00...
# ...                                                  ...
# 45013  00-0033199;00-0023252;00-0037829;00-0032701;00...
# 45029  00-0033199;00-0023252;00-0037829;00-0032701;00...
# 45038  00-0034759;00-0033290;00-0031561;00-0037322;00...
# 45064  00-0033199;00-0023252;00-0037829;00-0033221;00...
# 45072  00-0033199;00-0023252;00-0037829;00-0032701;00...
#
#                                          defense_players n_offense  n_defense
# 32     00-0037190;00-0036500;00-0034374;00-0035718;00...        11         11
# 51     00-0036081;00-0036157;00-0033294;00-0026190;00...        11         11
# 82     00-0036081;00-0036157;00-0033294;00-0026190;00...        11         11
# 226    00-0036421;00-0035933;00-0032889;00-0036419;00...        11         11
# 259    00-0035352;00-0034673;00-0030114;00-0036166;00...        11         11
# ...                                                  ...       ...        ...
# 45013  00-0032496;00-0037517;00-0035674;00-0036989;00...        11         11
# 45029  00-0032496;00-0037517;00-0035674;00-0036989;00...        11         11
# 45038  00-0036563;00-0035279;00-0036564;00-0034091;00...        11         11
# 45064  00-0032496;00-0037517;00-0035674;00-0036989;00...        11         11
# 45072  00-0032496;00-0037517;00-0035674;00-0036989;00...        11         11
#
# [999 rows x 25 columns]

# %%
fg_df['field_goal_result'].unique()
# Out:
# array(['made', 'missed', 'blocked'], dtype=object)

# %%
pat_df
# Out:
#        week    play_type kicker_player_name kicker_player_id  \
# 69        1  extra_point           J.Tucker       00-0029597
# 104       1  extra_point           J.Tucker       00-0029597
# 118       1  extra_point           J.Tucker       00-0029597
# 174       1  extra_point         G.Zuerlein       00-0029621
# 190       1  extra_point             T.Bass       00-0036162
# ...     ...          ...                ...              ...
# 44965    17  extra_point          D.Carlson       00-0034161
# 44980    17  extra_point          D.Carlson       00-0034161
# 44991    17  extra_point            R.Gould       00-0023252
# 45045    17  extra_point            R.Gould       00-0023252
# 45053    17  extra_point          D.Carlson       00-0034161
#
#        field_goal_attempt field_goal_result  kick_distance  \
# 69                    0.0              None           33.0
# 104                   0.0              None           33.0
# 118                   0.0              None           33.0
# 174                   0.0              None           33.0
# 190                   0.0              None           33.0
# ...                   ...               ...            ...
# 44965                 0.0              None           33.0
# 44980                 0.0              None           33.0
# 44991                 0.0              None           33.0
# 45045                 0.0              None           33.0
# 45053                 0.0              None           33.0
#
#        extra_point_attempt extra_point_result fantasy_player_name  ...  \
# 69                     1.0               good                None  ...
# 104                    1.0               good                None  ...
# 118                    1.0               good                None  ...
# 174                    1.0             failed                None  ...
# 190                    1.0               good                None  ...
# ...                    ...                ...                 ...  ...
# 44965                  1.0               good                None  ...
# 44980                  1.0               good                None  ...
# 44991                  1.0               good                None  ...
# 45045                  1.0               good                None  ...
# 45053                  1.0               good                None  ...
#
#        offense_formation offense_personnel  defenders_in_box  \
# 69                  None              None               NaN
# 104                 None              None               NaN
# 118                 None              None               NaN
# 174                 None              None               NaN
# 190                 None              None               NaN
# ...                  ...               ...               ...
# 44965               None              None               NaN
# 44980               None              None               NaN
# 44991               None              None               NaN
# 45045               None              None               NaN
# 45053               None              None               NaN
#
#       defense_personnel number_of_pass_rushers  \
# 69                 None                    NaN
# 104                None                    NaN
# 118                None                    NaN
# 174                None                    NaN
# 190                None                    NaN
# ...                 ...                    ...
# 44965              None                    NaN
# 44980              None                    NaN
# 44991              None                    NaN
# 45045              None                    NaN
# 45053              None                    NaN
#
#                                          players_on_play  \
# 69     47906;52578;54595;54469;53575;46186;47786;3313...
# 104    47906;52578;54595;54469;53575;46186;47786;3313...
# 118    47906;52578;54595;54469;53575;46186;47786;3313...
# 174    52578;43586;53059;53443;42371;42500;44999;3313...
# 190    48512;52512;43617;52835;39684;43335;42569;4487...
# ...                                                  ...
# 44965  46084;46757;47944;53609;44938;44972;46349;4615...
# 44980  53601;46084;47944;53609;44938;44972;46349;4615...
# 44991  43616;55105;47811;44387;30403;53508;48581;4621...
# 45045  43616;55105;44387;47811;30403;53508;48581;4621...
# 45053  53601;46084;47944;53609;44972;46349;46157;4241...
#
#                                          offense_players  \
# 69     00-0034978;00-0036081;00-0038094;00-0026190;00...
# 104    00-0034978;00-0036081;00-0038094;00-0026190;00...
# 118    00-0034978;00-0036081;00-0038094;00-0026190;00...
# 174    00-0032466;00-0036979;00-0032234;00-0032134;00...
# 190    00-0035382;00-0032497;00-0029685;00-0031622;00...
# ...                                                  ...
# 44965  00-0034759;00-0033290;00-0031561;00-0035190;00...
# 44980  00-0034759;00-0033290;00-0031561;00-0035190;00...
# 44991  00-0033199;00-0023252;00-0037829;00-0033221;00...
# 45045  00-0033199;00-0023252;00-0037829;00-0033221;00...
# 45053  00-0034759;00-0033290;00-0031561;00-0037322;00...
#
#                                          defense_players n_offense  n_defense
# 69     00-0037190;00-0036500;00-0034374;00-0035718;00...        11         11
# 104    00-0037190;00-0036500;00-0034374;00-0035718;00...        11         11
# 118    00-0037190;00-0036500;00-0034374;00-0035718;00...        11         11
# 174    00-0036081;00-0036157;00-0033294;00-0026190;00...        11         11
# 190    00-0036421;00-0035933;00-0032889;00-0036419;00...        11         11
# ...                                                  ...       ...        ...
# 44965  00-0034573;00-0035279;00-0036564;00-0033945;00...        11         11
# 44980  00-0036563;00-0035279;00-0036564;00-0033945;00...        11         11
# 44991  00-0032496;00-0037517;00-0035674;00-0036989;00...        11         11
# 45045  00-0032496;00-0037517;00-0035674;00-0036989;00...        11         11
# 45053  00-0036563;00-0035279;00-0036564;00-0034091;00...        11         11
#
# [1122 rows x 25 columns]

# %%
pat_df['extra_point_result'].unique()
# Out:
# array(['good', 'failed', 'blocked'], dtype=object)

# %%
kicker_data = {
    'player_display_name': [],
    'position': [],
    'fantasy_points_ppr': []
}

# Value each kicker
for i, name in enumerate(kicker_names):
    if name is None:
        continue
        
    # Get field goals and PATs for this kicker
    fg_i = fg_df[fg_df['kicker_player_name'] == name]
    pat_i = pat_df[pat_df['kicker_player_name'] == name]
    
    # Find the scores for each week
    for j in range(17):
        week = j + 1
        fg_j = fg_i[fg_i['week'] == j]
        pat_j = pat_i[pat_i['week'] == j]
        
        # Kicker scores
        fg_misses = -1 * len(fg_j[fg_j['field_goal_result'] != "made"].index)
        fg_made_3 = 3 * len(fg_j[(fg_j['field_goal_result'] == "made") & (fg_j['kick_distance'] < 40)])
        fg_made_4 = 4 * len(fg_j[(fg_j['field_goal_result'] == "made") & (fg_j['kick_distance'] < 50) & (fg_j['kick_distance'] >= 40)])
        fg_made_5 = 5 * len(fg_j[(fg_j['field_goal_result'] == "made") & (fg_j['kick_distance'] < 60) & (fg_j['kick_distance'] >= 50)])
        fg_made_6 = 6 * len(fg_j[(fg_j['field_goal_result'] == "made") & (fg_j['kick_distance'] >= 60)])
        pat_made = len(pat_j[pat_j['extra_point_result'] == 'good'])
        
        # Compute the score as a weighted sum
        score_j = fg_misses + fg_made_3 + fg_made_4 + fg_made_5 + fg_made_6 + pat_made
        
        # Add the score to the kicker weekly data
        kicker_data['player_display_name'].append(name)
        kicker_data['position'].append("K")
        kicker_data['fantasy_points_ppr'].append(score_j)

# %%
# Gather results into a dataframe and sort
kicker_results_df = pd.DataFrame(kicker_data)
kicker_results_df.head(30)
# Out:
#    player_display_name position  fantasy_points_ppr
# 0             J.Tucker        K                   0
# 1             J.Tucker        K                   6
# 2             J.Tucker        K                  10
# 3             J.Tucker        K                   9
# 4             J.Tucker        K                  11
# 5             J.Tucker        K                  16
# 6             J.Tucker        K                   7
# 7             J.Tucker        K                  13
# 8             J.Tucker        K                   8
# 9             J.Tucker        K                  10
# 10            J.Tucker        K                   0
# 11            J.Tucker        K                   7
# 12            J.Tucker        K                  14
# 13            J.Tucker        K                   4
# 14            J.Tucker        K                  11
# 15            J.Tucker        K                   3
# 16            J.Tucker        K                   8
# 17          G.Zuerlein        K                   0
# 18          G.Zuerlein        K                   3
# 19          G.Zuerlein        K                   9
# 20          G.Zuerlein        K                  18
# 21          G.Zuerlein        K                   6
# 22          G.Zuerlein        K                   8
# 23          G.Zuerlein        K                   8
# 24          G.Zuerlein        K                  12
# 25          G.Zuerlein        K                   4
# 26          G.Zuerlein        K                  10
# 27          G.Zuerlein        K                   0
# 28          G.Zuerlein        K                   4
# 29          G.Zuerlein        K                   8

# %%
# Export data
kicker_results_df.to_csv("kicker_ppr_data.csv")

# %% [markdown]
# # Weekly Data (All Other Players)

# %%
weekly_data = nfl.import_weekly_data([2022])
# Out:
# Downcasting floats.

# %%
weekly_data.head()
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0019596     T.Brady           Tom Brady       QB             QB
# 1  00-0019596     T.Brady           Tom Brady       QB             QB
# 2  00-0019596     T.Brady           Tom Brady       QB             QB
# 3  00-0019596     T.Brady           Tom Brady       QB             QB
# 4  00-0019596     T.Brady           Tom Brady       QB             QB
#
#                                         headshot_url recent_team  season  \
# 0  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 1  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 2  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 3  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 4  https://static.www.nfl.com/image/private/f_aut...          TB    2022
#
#    week season_type  ...  receiving_first_downs  receiving_epa  \
# 0     1         REG  ...                    0.0            NaN
# 1     2         REG  ...                    0.0            NaN
# 2     3         REG  ...                    0.0            NaN
# 3     4         REG  ...                    0.0            NaN
# 4     5         REG  ...                    0.0            NaN
#
#    receiving_2pt_conversions  racr  target_share  air_yards_share  wopr  \
# 0                          0   NaN           NaN              NaN   NaN
# 1                          0   NaN           NaN              NaN   NaN
# 2                          0   NaN           NaN              NaN   NaN
# 3                          0   NaN           NaN              NaN   NaN
# 4                          0   NaN           NaN              NaN   NaN
#
#    special_teams_tds  fantasy_points  fantasy_points_ppr
# 0                0.0           10.38               10.38
# 1                0.0            9.40                9.40
# 2                0.0           14.74               14.74
# 3                0.0           25.40               25.40
# 4                0.0           19.74               19.74
#
# [5 rows x 52 columns]

# %%
weekly_data['position'].unique()
# Out:
# array(['QB', 'P', 'TE', 'WR', 'RB', 'ILB', 'FB', 'T', 'FS', 'SS', 'OLB',
#        'CB'], dtype=object)

# %%
# only show data from week 17 and earlier (fantasy regular season and playoffs)
weekly_data = weekly_data[weekly_data['week'] <= 17]

# %%
# Get total fantasy points for each player via aggregation
week_agg = (
    weekly_data.groupby(["player_display_name", "position"], as_index=False)
    .agg({"fantasy_points_ppr": "sum"})
)

# %%
week_agg
# Out:
#     player_display_name position  fantasy_points_ppr
# 0            A.J. Brown       WR          286.100006
# 1           A.J. Dillon       RB          164.300003
# 2            A.J. Green       WR           43.500000
# 3           Aaron Jones       RB          240.800003
# 4         Aaron Rodgers       QB          228.000000
# ..                  ...      ...                 ...
# 597           Zack Moss       RB           43.400002
# 598         Zamir White       RB            6.600000
# 599      Zander Horvath       RB           18.600000
# 600           Zay Jones       WR          192.000000
# 601      Zonovan Knight       RB           56.799999
#
# [602 rows x 3 columns]

# %% [markdown]
# # Data Merging
#
# Merge the weekly data with the Kicker and D/ST data

# %%
week_player_df = weekly_data[["player_display_name", "position", "fantasy_points_ppr"]]
all_players_df = pd.concat([week_player_df, kicker_results_df], ignore_index=True)

# %%
all_players_df
# Out:
#      player_display_name position  fantasy_points_ppr
# 0              Tom Brady       QB               10.38
# 1              Tom Brady       QB                9.40
# 2              Tom Brady       QB               14.74
# 3              Tom Brady       QB               25.40
# 4              Tom Brady       QB               19.74
# ...                  ...      ...                 ...
# 6162            J.Hekker        K                0.00
# 6163            J.Hekker        K                0.00
# 6164            J.Hekker        K                0.00
# 6165            J.Hekker        K                0.00
# 6166            J.Hekker        K                0.00
#
# [6167 rows x 3 columns]

# %%
# Aggregate kicker weekly data
kicker_agg =(
    kicker_results_df.groupby(["player_display_name", "position"], as_index=False)
    .agg({"fantasy_points_ppr": "sum"})
)

# %%
agg_players_df = pd.concat([week_agg, kicker_agg], ignore_index=True)
agg_players_df.head(5)
# Out:
#   player_display_name position  fantasy_points_ppr
# 0          A.J. Brown       WR          286.100006
# 1         A.J. Dillon       RB          164.300003
# 2          A.J. Green       WR           43.500000
# 3         Aaron Jones       RB          240.800003
# 4       Aaron Rodgers       QB          228.000000

# %% [markdown]
# # Replacement Levels

# %%
positions = ["QB", "RB", "WR", "TE", "K"] # Still need a way to get D/ST data.
position_dfs = {}

# Separate results by position
for p in positions:
    position_dfs[p] = agg_players_df[agg_players_df['position'] == p]
    position_dfs[p] = position_dfs[p].sort_values('fantasy_points_ppr', ascending=False)

# %%
# Example
position_dfs['K'].head(25)
# Out:
#     player_display_name position  fantasy_points_ppr
# 604             B.Maher        K               149.0
# 615           D.Carlson        K               138.0
# 637            J.Tucker        K               137.0
# 659              T.Bass        K               134.0
# 632             J.Myers        K               134.0
# 620           E.Pineiro        K               132.0
# 621              G.Gano        K               130.0
# 648              N.Folk        K               130.0
# 666               Y.Koo        K               124.0
# 623          G.Zuerlein        K               121.0
# 611        C.McLaughlin        K               120.0
# 638         K.Fairbairn        K               119.0
# 655         R.Patterson        K               118.0
# 657            R.Succop        K               118.0
# 619         E.McPherson        K               117.0
# 654             R.Gould        K               116.0
# 644               M.Gay        K               116.0
# 634           J.Sanders        K               116.0
# 606           B.McManus        K               113.0
# 622            G.Joseph        K               110.0
# 614              C.York        K               105.0
# 636              J.Slye        K                99.0
# 665              W.Lutz        K                98.0
# 612            C.Santos        K                97.0
# 641           M.Badgley        K                95.0

# %%
# compute replacement level player for each position group
# Lineup format: QB, 2x RB, 2x WR, 1x TE, 1x FLEX, D/ST, K
#
# We will define replacement level as the average player for a 
# given position who would not be on a starting lineup on a team
# For example, the 13th best QB would not make the starting lineup
# in a 12 team league.
# 
#
# Replacement level QB: average pts. for ranks #13-24
# Replacement level RB: average pts. for ranks #25-48
# Replacement level WR: average pts. for ranks #25-48
# Replacement level TE: average pts. for ranks #13-24
# Replacement level FLEX: since FLEX is RB/WR/TE, use the position WAR.
# Replacement level K: average pts. for ranks #13-24
#
# Zero-index and upper bound is not inclusive
pos_ranges = {
    'QB': [12, 24],
    'RB': [24, 48],
    'WR': [24, 48],
    'TE': [12, 24],
    'K' : [12, 24]
}

position_replacements = {}

for p in positions:
    pos_range = position_dfs[p].iloc[pos_ranges[p][0]:pos_ranges[p][1]]
    
    pos_avg = []
    pos_s2 = []
    for i, row in pos_range.iterrows():
        name = row['player_display_name']
        avg, s2, _ = player_dist(all_players_df, name)
#         if row['position'] == 'K':
#             print(f"{name} - Avg: {avg}, s2: {s2}")
        pos_avg.append(avg)
        pos_s2.append(s2)
        
    position_replacements[p] = {}
    position_replacements[p]['avg'] = np.average(pos_avg)
    position_replacements[p]['s2'] = np.average(pos_s2)

# %%
# Compute FLEX as a weighted average of RB, WR and TE
flex_options = ['RB', 'WR', 'TE']
flex_weights = [0.4, 0.5, 0.1]

flex_avg = 0
flex_s2 = 0
for i in range(len(flex_options)):
    avg = position_replacements[flex_options[i]]['avg']
    s2 = position_replacements[flex_options[i]]['s2']
    
    flex_avg += avg * flex_weights[i]
    flex_s2 += s2 * flex_weights[i]
    
position_replacements['FLEX'] = {
    'avg': flex_avg,
    's2': flex_s2
}

# %%
# Manual augmentation of K and D/ST
# position_replacements['K'] = {
#     'avg': 6,
#     's2': 16
# }
position_replacements['DST'] = {
    'avg': 5,
    's2': 25
}

# %%
position_replacements
# Out:
# {'QB': {'avg': 15.393755812724443, 's2': 47.68247335819177},
#  'RB': {'avg': 9.839898333388298, 's2': 45.30572088325123},
#  'WR': {'avg': 11.436712445779051, 's2': 44.9141276239626},
#  'TE': {'avg': 7.948062050411697, 's2': 26.334732925240605},
#  'K': {'avg': 6.485294117647059, 's2': 21.140715109573236},
#  'FLEX': {'avg': 10.449121761286014, 's2': 43.21282545780585},
#  'DST': {'avg': 5, 's2': 25}}

# %%
# Compute a PPR team as a normal distribution using sampling
N = 1000

# Lineup for the team
lineup = ['QB', 'RB', 'RB', 'WR', 'WR', 'TE', 'FLEX', 'DST', 'K']

# Sample the team
ppr_repl_team_scores = sample_ppr_repl_team(position_replacements, lineup, N)

# %%
repl_avg = np.average(ppr_repl_team_scores)
repl_sigma = np.std(ppr_repl_team_scores)
print(f"Replacement level team - AVG: {repl_avg} - SIGMA: {repl_sigma}")
# Out:
# Replacement level team - AVG: 88.00950608070993 - SIGMA: 19.0392769794656

# %%
plot_samples(ppr_repl_team_scores, repl_avg, repl_sigma)

# %% [markdown]
# # WAR Ranks

# %%
player_list_df = agg_players_df
PPR_LINEUP = ['QB', 'RB', 'RB', 'WR', 'WR', 'TE', 'FLEX', 'DST', 'K']
N = 10000
MIN_GAMES = 3

# %%
war_data = {'player_display_name':[], 'position': [], 'n_games':[], 'mu': [], 'sigma': [], 'wpa': [], 'war': []}

for i, row in player_list_df.iterrows():
    # Copy the lineup explicitly since we will modify it.
    mod_lineup = list.copy(PPR_LINEUP)
    
    # Get player info
    name = row['player_display_name']
    pos = row['position']
    p_mu, p_sigma, p_games = player_dist(all_players_df, name)
    
    # Remove position from lineup if it exists, or if the player did not play at least 3 games
    if pos not in PPR_LINEUP or p_games < MIN_GAMES:
        continue
    mod_lineup.remove(pos)
    
    # Sample a replacement team's score with this player added
    mod_team_scores = sample_ppr_repl_team(position_replacements, mod_lineup, N)
    player_samples = sample_player(all_players_df, name, N)
    player_team_scores = mod_team_scores + player_samples
    
    # Get this fictitious team's normal distribution parameters
    player_team_avg = np.average(player_team_scores)
    player_team_sigma = np.std(player_team_scores)
    
    # Compute WPA and WAR
    player_wpa = norm.cdf(player_team_avg, loc=repl_avg, scale=repl_sigma) - 0.5
    player_war = p_games * player_wpa

    # Update the dictionary
    war_data['player_display_name'].append(name)
    war_data['position'].append(pos)
    war_data['n_games'].append(p_games)
    war_data['mu'].append(p_mu)
    war_data['sigma'].append(np.sqrt(p_sigma))
    war_data['wpa'].append(player_wpa)
    war_data['war'].append(player_war)

# %%
war_df = pd.DataFrame(war_data)

# %%
war_df = war_df.sort_values(by=['war'], ascending=False, ignore_index=True)
pd.set_option('display.max_rows', 500)
war_df.head(50)
# Out:
#     player_display_name position  n_games         mu      sigma       wpa  \
# 0         Austin Ekeler       RB       16  22.731250   8.369044  0.251843
# 1          Travis Kelce       TE       16  19.156250   7.589958  0.224124
# 2      Justin Jefferson       WR       16  22.553750  11.495085  0.220948
# 3   Christian McCaffrey       RB       16  21.216250   8.457760  0.219660
# 4           Josh Jacobs       RB       16  20.081250  11.605991  0.211342
# 5           Tyreek Hill       WR       16  21.056250   8.943711  0.192473
# 6       Patrick Mahomes       QB       16  25.151250   5.977345  0.190320
# 7           Jalen Hurts       QB       14  26.398571   5.855701  0.214887
# 8         Davante Adams       WR       16  20.200000  11.897794  0.179128
# 9         Derrick Henry       RB       15  19.264000   8.395094  0.187939
# 10           Josh Allen       QB       15  24.917333   6.546836  0.182999
# 11       Saquon Barkley       RB       16  17.750000   7.281913  0.158605
# 12         Stefon Diggs       WR       15  19.546667  10.035794  0.165041
# 13           Joe Burrow       QB       15  22.606667   6.811652  0.145176
# 14         Tony Pollard       RB       15  16.460000   9.784055  0.143570
# 15           A.J. Brown       WR       16  17.881250   9.275924  0.130463
# 16          CeeDee Lamb       WR       16  17.837500   8.653892  0.128745
# 17           Nick Chubb       RB       16  16.137500   7.023966  0.128629
# 18            Joe Mixon       RB       13  17.053846  11.694878  0.153216
# 19          Cooper Kupp       WR        9  22.377778   8.639416  0.211910
# 20        Ja'Marr Chase       WR       11  19.981818   8.435511  0.169968
# 21       T.J. Hockenson       TE       16  13.300000   9.933530  0.111806
# 22          Aaron Jones       RB       16  15.050000   7.900554  0.110926
# 23    Amon-Ra St. Brown       WR       15  17.113333   9.960781  0.115778
# 24    Leonard Fournette       RB       15  14.980000   7.564496  0.109717
# 25  Rhamondre Stevenson       RB       16  14.743750   7.597365  0.098605
# 26          Dalvin Cook       RB       16  14.693750   6.829849  0.097007
# 27        George Kittle       TE       14  12.971428   8.735022  0.110337
# 28         Mark Andrews       TE       15  12.700000   8.727963  0.099664
# 29         James Conner       RB       13  15.400000   6.118698  0.113374
# 30        Jaylen Waddle       WR       16  15.556250   9.855326  0.086983
# 31          Tee Higgins       WR       13  16.861538   6.346839  0.103753
# 32        Justin Fields       QB       15  19.732000  10.253207  0.087036
# 33         Alvin Kamara       RB       14  14.264286   9.529024  0.093236
# 34        DeVonta Smith       WR       16  15.056250   8.511681  0.079293
# 35        Miles Sanders       RB       16  13.337500   8.965062  0.077803
# 36         Amari Cooper       WR       16  14.931250   8.516874  0.070262
# 37           Mike Evans       WR       15  15.026667  10.963969  0.074769
# 38         Najee Harris       RB       16  13.091250   4.879667  0.068853
# 39        Tyler Lockett       WR       15  14.926667   6.907529  0.072625
# 40         Chris Godwin       WR       14  15.235714   5.610272  0.076553
# 41          Evan Engram       TE       16  10.637500   9.025511  0.066056
# 42      Jamaal Williams       RB       16  12.918750   7.923164  0.064089
# 43      DeAndre Hopkins       WR        9  16.855556   8.137583  0.111394
# 44        Lamar Jackson       QB       12  19.673333  11.001982  0.080939
# 45        D'Andre Swift       RB       13  13.500000   7.279687  0.073592
# 46      Ezekiel Elliott       RB       14  13.200000   4.303487  0.066033
# 47       Kenneth Walker       RB       14  13.507143   7.755133  0.065734
# 48          Breece Hall       RB        7  16.442857   5.407101  0.128901
# 49           DK Metcalf       WR       16  13.737500   6.911573  0.055245
#
#          war
# 0   4.029487
# 1   3.585980
# 2   3.535170
# 3   3.514558
# 4   3.381476
# 5   3.079575
# 6   3.045125
# 7   3.008418
# 8   2.866053
# 9   2.819085
# 10  2.744983
# 11  2.537673
# 12  2.475616
# 13  2.177636
# 14  2.153556
# 15  2.087410
# 16  2.059922
# 17  2.058068
# 18  1.991812
# 19  1.907188
# 20  1.869651
# 21  1.788895
# 22  1.774815
# 23  1.736663
# 24  1.645752
# 25  1.577686
# 26  1.552116
# 27  1.544719
# 28  1.494959
# 29  1.473863
# 30  1.391728
# 31  1.348785
# 32  1.305544
# 33  1.305304
# 34  1.268695
# 35  1.244842
# 36  1.124186
# 37  1.121530
# 38  1.101646
# 39  1.089371
# 40  1.071748
# 41  1.056893
# 42  1.025420
# 43  1.002550
# 44  0.971266
# 45  0.956694
# 46  0.924461
# 47  0.920283
# 48  0.902308
# 49  0.883913

# %%
war_df.to_csv("player_war.csv", index=False)

# %% [markdown]
# # Position Breakdown

# %%
def plot_position_war(df, pos, n_show = None):
    war_np = df["war"].to_numpy()
    n_players =  len(df.index)
    
    if n_show is not None:
        n_players = n_show
        war_np = war_np[0:n_show]
    
    ranks_np = np.linspace(1, n_players, n_players)
    
    plt.figure()
    plt.grid()
    plt.scatter(ranks_np, war_np)
    plt.xlabel("Ranks")
    plt.ylabel("WAR")
    plt.title(f"{pos} WAR Rankings")
    plt.show()

# %%
position_queries = ['QB', 'RB', 'WR', 'TE', 'K']

# %%
for i, pos in enumerate(position_queries):
    pos_war_df = war_df[war_df['position'] == pos]
    
    plot_position_war(pos_war_df, pos, 25)

# %% [markdown]
# # Basic WAR Draft Strategy
#
# Given perfect knowledge, a good draft strategy would be to simply pick the highest WAR player available to fill out the starting lineup, and then pick best WAR available for the remainder of the draft (while picking K and D/ST at some point).
#
# This isn't guaranteed to be the best strategy - a rigorous Monte-Carlo Tree Search (MCTS) would likely be needed to reveal a better strategy for this multiplayer game theory problem. So instead, we will see how this naive strategy would have performed for a 12 team PPR draft

# %%
N_TEAMS = 12
teams = []

rules = {
    'QB': {
        'min': 1
    },
    'RB': 
    {
        'min': 2
    },
    'WR': 
    {
        'min': 2
    },
    'TE': 
    {
        'min': 1
    }
    
}

# Build the list of empty teams
for i in range(N_TEAMS):
    teams.append({
        'QB': [None],
        'RB': [None, None, None],
        'WR': [None, None, None],
        'TE': [None, None]
    })

# Do a snake draft
N_ROUNDS = 7 # 7 rounds to fill out the relevant parts of the starting lineup

# Save the draft results
draft_order = {
    'pick': [],
    'player_display_name': [],
    'war': []
}

# Maintain a copy of the WAR dataframe. This is sorted by WAR from highest to lowest.
draftable_players = pd.read_csv("player_war.csv")

# Round / team indexing
cur_round = 1
team_idx = 0
for i in range(N_TEAMS * N_ROUNDS):
    # Drafted player information
    player_info = {
        'name': None,
        'war': None
    }
    found_player = False
    
    # Find the best WAR player who can fill an open spot on this team's starting lineup.
    for j, row in draftable_players.iterrows():
        pos = row['position']
        for k in range(len(teams[team_idx][pos])):
            # Draft the player if the position group is not at its minimum, or this is the last round
            if ((teams[team_idx][pos][k] is None) and (k < rules[pos]['min'] or cur_round == N_ROUNDS)):
                player_info['name'] = row['player_display_name']
                player_info['war'] = row['war']
                teams[team_idx][pos][k] = player_info
                found_player = True
                break

        # If a player has been drafted, stop searching
        if found_player is True:
            break
    
    # Register the player as drafted
    draft_order['pick'].append(i + 1)
    draft_order['player_display_name'].append(player_info['name'])
    draft_order['war'].append(player_info['war'])
    
    # Print draft status
    print(f"Team {team_idx + 1} - Round {cur_round}, Pick: {i + 1}: {player_info['name']}")
    
    # Remove the player from the draftable list.
    draftable_players = draftable_players[draftable_players['player_display_name'] != player_info['name']]
    
    # Increment or decrement the team index based on the current round
    if cur_round % 2 == 1:
        if team_idx < (N_TEAMS - 1):
            team_idx += 1
        else:
            cur_round += 1
    else:
        if team_idx > 0:
            team_idx -= 1
        else:
            cur_round += 1
# Out:
# Team 1 - Round 1, Pick: 1: Austin Ekeler
# Team 2 - Round 1, Pick: 2: Christian McCaffrey
# Team 3 - Round 1, Pick: 3: Justin Jefferson
# Team 4 - Round 1, Pick: 4: Travis Kelce
# Team 5 - Round 1, Pick: 5: Josh Jacobs
# Team 6 - Round 1, Pick: 6: Patrick Mahomes
# Team 7 - Round 1, Pick: 7: Tyreek Hill
# Team 8 - Round 1, Pick: 8: Jalen Hurts
# Team 9 - Round 1, Pick: 9: Davante Adams
# Team 10 - Round 1, Pick: 10: Derrick Henry
# Team 11 - Round 1, Pick: 11: Josh Allen
# Team 12 - Round 1, Pick: 12: Saquon Barkley
# Team 12 - Round 2, Pick: 13: Stefon Diggs
# Team 11 - Round 2, Pick: 14: A.J. Brown
# Team 10 - Round 2, Pick: 15: Joe Burrow
# Team 9 - Round 2, Pick: 16: Joe Mixon
# Team 8 - Round 2, Pick: 17: CeeDee Lamb
# Team 7 - Round 2, Pick: 18: Cooper Kupp
# Team 6 - Round 2, Pick: 19: Nick Chubb
# Team 5 - Round 2, Pick: 20: Tony Pollard
# Team 4 - Round 2, Pick: 21: Ja'Marr Chase
# Team 3 - Round 2, Pick: 22: T.J. Hockenson
# Team 2 - Round 2, Pick: 23: Amon-Ra St. Brown
# Team 1 - Round 2, Pick: 24: Aaron Jones
# Team 1 - Round 3, Pick: 25: Mark Andrews
# Team 2 - Round 3, Pick: 26: Leonard Fournette
# Team 3 - Round 3, Pick: 27: Rhamondre Stevenson
# Team 4 - Round 3, Pick: 28: Dalvin Cook
# Team 5 - Round 3, Pick: 29: Tee Higgins
# Team 6 - Round 3, Pick: 30: George Kittle
# Team 7 - Round 3, Pick: 31: James Conner
# Team 8 - Round 3, Pick: 32: Jaylen Waddle
# Team 9 - Round 3, Pick: 33: Justin Fields
# Team 10 - Round 3, Pick: 34: Alvin Kamara
# Team 11 - Round 3, Pick: 35: Miles Sanders
# Team 12 - Round 3, Pick: 36: DeVonta Smith
# Team 12 - Round 4, Pick: 37: Evan Engram
# Team 11 - Round 4, Pick: 38: Mike Evans
# Team 10 - Round 4, Pick: 39: Amari Cooper
# Team 9 - Round 4, Pick: 40: D'Andre Swift
# Team 8 - Round 4, Pick: 41: Najee Harris
# Team 7 - Round 4, Pick: 42: Kenneth Walker
# Team 6 - Round 4, Pick: 43: DeAndre Hopkins
# Team 5 - Round 4, Pick: 44: Chris Godwin
# Team 4 - Round 4, Pick: 45: Tyler Lockett
# Team 3 - Round 4, Pick: 46: Breece Hall
# Team 2 - Round 4, Pick: 47: Lamar Jackson
# Team 1 - Round 4, Pick: 48: Daniel Jones
# Team 1 - Round 5, Pick: 49: Keenan Allen
# Team 2 - Round 5, Pick: 50: Dallas Goedert
# Team 3 - Round 5, Pick: 51: Geno Smith
# Team 4 - Round 5, Pick: 52: Jamaal Williams
# Team 5 - Round 5, Pick: 53: Zach Ertz
# Team 6 - Round 5, Pick: 54: Ezekiel Elliott
# Team 7 - Round 5, Pick: 55: Pat Freiermuth
# Team 8 - Round 5, Pick: 56: Jonathan Taylor
# Team 9 - Round 5, Pick: 57: Brandon Aiyuk
# Team 10 - Round 5, Pick: 58: Christian Kirk
# Team 11 - Round 5, Pick: 59: Dameon Pierce
# Team 12 - Round 5, Pick: 60: Trevor Lawrence
# Team 12 - Round 6, Pick: 61: Travis Etienne
# Team 11 - Round 6, Pick: 62: David Njoku
# Team 10 - Round 6, Pick: 63: Dalton Schultz
# Team 9 - Round 6, Pick: 64: Darren Waller
# Team 8 - Round 6, Pick: 65: Tyler Higbee
# Team 7 - Round 6, Pick: 66: Kyler Murray
# Team 6 - Round 6, Pick: 67: DK Metcalf
# Team 5 - Round 6, Pick: 68: Tua Tagovailoa
# Team 4 - Round 6, Pick: 69: Kirk Cousins
# Team 3 - Round 6, Pick: 70: Mike Williams
# Team 2 - Round 6, Pick: 71: Michael Pittman
# Team 1 - Round 6, Pick: 72: Terry McLaurin
# Team 1 - Round 7, Pick: 73: Jerick McKinnon
# Team 2 - Round 7, Pick: 74: David Montgomery
# Team 3 - Round 7, Pick: 75: Marquise Brown
# Team 4 - Round 7, Pick: 76: Cordarrelle Patterson
# Team 5 - Round 7, Pick: 77: Devin Singletary
# Team 6 - Round 7, Pick: 78: Deebo Samuel
# Team 7 - Round 7, Pick: 79: Michael Thomas
# Team 8 - Round 7, Pick: 80: Chris Olave
# Team 9 - Round 7, Pick: 81: Jakobi Meyers
# Team 10 - Round 7, Pick: 82: Zay Jones
# Team 11 - Round 7, Pick: 83: Taysom Hill
# Team 12 - Round 7, Pick: 84: Jerry Jeudy

# %%
def pretty_print_teams(teams):
    for i, team in enumerate(teams):
        war = 0
        print(f"Team #{i + 1}:")
        for key in team.keys():
            for player in team[key]:
                if player is not None:
                    print(f"{key}: {player['name']}")
                    war += player['war']
        print(f"Total WAR: {war}")
        print("---------------------------------------")
        
def rank_teams(teams):
    war_list = []
    for i, team in enumerate(teams):
        war = 0
        for key in team.keys():
            for player in team[key]:
                if player is not None:
                    war += player['war']
        war_list.append(war)
    return war_list

pretty_print_teams(teams)
# Out:
# Team #1:
# QB: Daniel Jones
# RB: Austin Ekeler
# RB: Aaron Jones
# RB: Jerick McKinnon
# WR: Keenan Allen
# WR: Terry McLaurin
# TE: Mark Andrews
# Total WAR: 9.082124509921236
# ---------------------------------------
# Team #2:
# QB: Lamar Jackson
# RB: Christian McCaffrey
# RB: Leonard Fournette
# RB: David Montgomery
# WR: Amon-Ra St. Brown
# WR: Michael Pittman
# TE: Dallas Goedert
# Total WAR: 9.10602520571174
# ---------------------------------------
# Team #3:
# QB: Geno Smith
# RB: Rhamondre Stevenson
# RB: Breece Hall
# WR: Justin Jefferson
# WR: Mike Williams
# WR: Marquise Brown
# TE: T.J. Hockenson
# Total WAR: 8.894679371599675
# ---------------------------------------
# Team #4:
# QB: Kirk Cousins
# RB: Dalvin Cook
# RB: Jamaal Williams
# RB: Cordarrelle Patterson
# WR: Ja'Marr Chase
# WR: Tyler Lockett
# TE: Travis Kelce
# Total WAR: 8.871813234405014
# ---------------------------------------
# Team #5:
# QB: Tua Tagovailoa
# RB: Josh Jacobs
# RB: Tony Pollard
# RB: Devin Singletary
# WR: Tee Higgins
# WR: Chris Godwin
# TE: Zach Ertz
# Total WAR: 8.745521894134564
# ---------------------------------------
# Team #6:
# QB: Patrick Mahomes
# RB: Nick Chubb
# RB: Ezekiel Elliott
# WR: DeAndre Hopkins
# WR: DK Metcalf
# WR: Deebo Samuel
# TE: George Kittle
# Total WAR: 8.491031049153001
# ---------------------------------------
# Team #7:
# QB: Kyler Murray
# RB: James Conner
# RB: Kenneth Walker
# WR: Tyreek Hill
# WR: Cooper Kupp
# WR: Michael Thomas
# TE: Pat Freiermuth
# Total WAR: 8.156772951235961
# ---------------------------------------
# Team #8:
# QB: Jalen Hurts
# RB: Najee Harris
# RB: Jonathan Taylor
# WR: CeeDee Lamb
# WR: Jaylen Waddle
# WR: Chris Olave
# TE: Tyler Higbee
# Total WAR: 8.23347938976587
# ---------------------------------------
# Team #9:
# QB: Justin Fields
# RB: Joe Mixon
# RB: D'Andre Swift
# WR: Davante Adams
# WR: Brandon Aiyuk
# WR: Jakobi Meyers
# TE: Darren Waller
# Total WAR: 8.01400426438766
# ---------------------------------------
# Team #10:
# QB: Joe Burrow
# RB: Derrick Henry
# RB: Alvin Kamara
# WR: Amari Cooper
# WR: Christian Kirk
# WR: Zay Jones
# TE: Dalton Schultz
# Total WAR: 8.044690398054419
# ---------------------------------------
# Team #11:
# QB: Josh Allen
# RB: Miles Sanders
# RB: Dameon Pierce
# WR: A.J. Brown
# WR: Mike Evans
# TE: David Njoku
# TE: Taysom Hill
# Total WAR: 8.008522134861007
# ---------------------------------------
# Team #12:
# QB: Trevor Lawrence
# RB: Saquon Barkley
# RB: Travis Etienne
# WR: Stefon Diggs
# WR: DeVonta Smith
# WR: Jerry Jeudy
# TE: Evan Engram
# Total WAR: 7.830517035189991
# ---------------------------------------

# %%
ranks = rank_teams(teams)
ranks = np.array(ranks)
x = np.linspace(1, N_TEAMS, N_TEAMS)

plt.figure()
plt.grid()
plt.scatter(x, ranks)
plt.xlabel("Draft Order")
plt.ylabel("Team WAR")
plt.title("Team WAR vs. Draft Position")
plt.show()

# %% [markdown]
# # Position Rank Lookup (TESTING)

# %%
pos = 'RB'
pos_war_df = war_df[war_df['position'] == pos]
pos_war_df = pos_war_df.reset_index(drop = True)
pos_war_df.head(50)
# Out:
#       player_display_name position  n_games         mu      sigma       wpa  \
# 0           Austin Ekeler       RB       16  22.731251   8.369044  0.236156
# 1     Christian McCaffrey       RB       16  21.216249   8.457760  0.214164
# 2             Josh Jacobs       RB       16  20.081249  11.605990  0.195143
# 3           Derrick Henry       RB       15  19.264000   8.395094  0.183079
# 4          Saquon Barkley       RB       16  17.750000   7.281913  0.142286
# 5            Tony Pollard       RB       15  16.460001   9.784056  0.129782
# 6              Nick Chubb       RB       16  16.137501   7.023965  0.116199
# 7               Joe Mixon       RB       13  17.053846  11.694878  0.137686
# 8             Aaron Jones       RB       16  15.050000   7.900554  0.091159
# 9     Rhamondre Stevenson       RB       16  14.743750   7.597365  0.089989
# 10           James Conner       RB       13  15.400000   6.118698  0.105746
# 11            Dalvin Cook       RB       16  14.693750   6.829849  0.084207
# 12      Leonard Fournette       RB       15  14.980000   7.564497  0.089104
# 13           Alvin Kamara       RB       14  14.264284   9.529024  0.080481
# 14          Miles Sanders       RB       16  13.337501   8.965062  0.063183
# 15         Kenneth Walker       RB       14  13.507142   7.755133  0.066472
# 16          D'Andre Swift       RB       13  13.500000   7.279687  0.068518
# 17        Jamaal Williams       RB       16  12.918751   7.923164  0.055123
# 18        Ezekiel Elliott       RB       14  13.200002   4.303487  0.058941
# 19            Breece Hall       RB        7  16.442858   5.407101  0.113216
# 20           Najee Harris       RB       16  13.091249   4.879667  0.048901
# 21          Dameon Pierce       RB       13  12.800001   6.189197  0.052972
# 22        Jonathan Taylor       RB       11  13.309092   7.891705  0.061865
# 23        Jerick McKinnon       RB       16  11.731250   9.667001  0.035391
# 24         Travis Etienne       RB       16  12.356250   7.536243  0.032665
# 25  Cordarrelle Patterson       RB       12  12.066666   6.946022  0.036433
# 26       Devin Singletary       RB       15  11.713334   5.568347  0.025728
# 27       David Montgomery       RB       15  11.706667   6.289936  0.019687
# 28         Antonio Gibson       RB       15  11.059999   4.931640  0.015472
# 29        Latavius Murray       RB       12  11.283333   4.248693  0.011561
# 30          Rashaad Penny       RB        5  10.440001   9.468179  0.012658
# 31         Raheem Mostert       RB       15  10.679999   6.938318  0.004154
# 32       Javonte Williams       RB        4  10.500000   5.830523  0.002770
# 33  Clyde Edwards-Helaire       RB       10   9.830000   8.098648 -0.001072
# 34           J.K. Dobbins       RB        8  10.150000   6.768124 -0.007062
# 35            A.J. Dillon       RB       16  10.268750   6.383056 -0.007319
# 36         Zonovan Knight       RB        6   9.466666   6.047772 -0.021207
# 37         Jeffery Wilson       RB       15   9.940001   6.454125 -0.013732
# 38         Khalil Herbert       RB       12   9.325000   8.145564 -0.019861
# 39            Benny Snell       RB        3   6.233333   5.606147 -0.080837
# 40         Tyler Allgeier       RB       15   9.726667   5.986592 -0.016227
# 41         Brian Robinson       RB       12   9.391666   5.197188 -0.021759
# 42            Marlon Mack       RB        5   7.660000   6.813105 -0.053421
# 43          Royce Freeman       RB        3   6.100000   0.927362 -0.093896
# 44          Pierre Strong       RB        4   6.800000   6.288481 -0.070478
# 45        Phillip Lindsay       RB        3   4.933333   3.465384 -0.109743
# 46              Cam Akers       RB       14   8.964286   9.014719 -0.024038
# 47        Elijah Mitchell       RB        4   6.525000   2.064431 -0.085725
# 48         D'Onta Foreman       RB       15   8.280000   9.531295 -0.023976
# 49          Samaje Perine       RB       15   9.259999   8.210709 -0.024733
#
#          war
# 0   3.778489
# 1   3.426629
# 2   3.122288
# 3   2.746182
# 4   2.276578
# 5   1.946734
# 6   1.859184
# 7   1.789915
# 8   1.458549
# 9   1.439825
# 10  1.374693
# 11  1.347313
# 12  1.336553
# 13  1.126739
# 14  1.010926
# 15  0.930603
# 16  0.890731
# 17  0.881967
# 18  0.825167
# 19  0.792511
# 20  0.782412
# 21  0.688637
# 22  0.680515
# 23  0.566250
# 24  0.522646
# 25  0.437195
# 26  0.385924
# 27  0.295307
# 28  0.232082
# 29  0.138730
# 30  0.063289
# 31  0.062306
# 32  0.011081
# 33 -0.010716
# 34 -0.056494
# 35 -0.117111
# 36 -0.127242
# 37 -0.205980
# 38 -0.238331
# 39 -0.242510
# 40 -0.243400
# 41 -0.261113
# 42 -0.267106
# 43 -0.281689
# 44 -0.281913
# 45 -0.329228
# 46 -0.336530
# 47 -0.342900
# 48 -0.359643
# 49 -0.370988

# %% [markdown]
# # Testing

# %%
df_2022 = nfl.import_pbp_data([2022])
df_players = nfl.import_rosters([2022])
df_teams = nfl.import_team_desc()

print(df_players.columns)
# Out:
# 2022 done.
# Downcasting floats.
# Index(['season', 'team', 'position', 'depth_chart_position', 'jersey_number',
#        'status', 'player_name', 'first_name', 'last_name', 'birth_date',
#        'height', 'weight', 'college', 'player_id', 'espn_id', 'sportradar_id',
#        'yahoo_id', 'rotowire_id', 'pff_id', 'pfr_id', 'fantasy_data_id',
#        'sleeper_id', 'years_exp', 'headshot_url', 'ngs_position', 'week',
#        'game_type', 'status_description_abbr', 'football_name', 'esb_id',
#        'gsis_it_id', 'smart_id', 'entry_year', 'rookie_year', 'draft_club',
#        'draft_number'],
#       dtype='object')

# %%
df_players[df_players['position'] == 'K']
# Out:
# Empty DataFrame
# Columns: [season, team, position, depth_chart_position, jersey_number, status, player_name, first_name, last_name, birth_date, height, weight, college, player_id, espn_id, sportradar_id, yahoo_id, rotowire_id, pff_id, pfr_id, fantasy_data_id, sleeper_id, years_exp, headshot_url, ngs_position, week, game_type, status_description_abbr, football_name, esb_id, gsis_it_id, smart_id, entry_year, rookie_year, draft_club, draft_number]
# Index: []
#
# [0 rows x 36 columns]

# %%
# Filter to only the data needed for fantasy football
df_2022 = df_2022[df_2022["season_type"] == "REG"]
df_2022 = df_2022[df_2022["week"] <= 17]

# %%
# Add team info
df_2022 = df_2022.merge(df_teams[["team_abbr", "team_color"]], left_on="posteam", right_on="team_abbr")

# %%
stats = ["passing_yards", "pass_touchdown", "interception", "fumble_lost", "rushing_yards", "rush_touchdown", "receiving_yards", "touchdown"]
stat_dict = dict()
for s in stats:
    stat_dict[s] = "sum"
    
df_agg = (
    df_2022.groupby(["name", "team_abbr", "team_color", "week"], as_index=False)
    .agg(stat_dict)
)

# %%
df_agg[df_agg["name"] == "J.Allen"]
# Out:
#         name team_abbr team_color  week  passing_yards  pass_touchdown  \
# 886  J.Allen       BUF    #00338D     1          297.0             3.0
# 887  J.Allen       BUF    #00338D     2          317.0             4.0
# 888  J.Allen       BUF    #00338D     3          400.0             2.0
# 889  J.Allen       BUF    #00338D     4          213.0             1.0
# 890  J.Allen       BUF    #00338D     5          424.0             4.0
# 891  J.Allen       BUF    #00338D     6          329.0             3.0
# 892  J.Allen       BUF    #00338D     8          218.0             2.0
# 893  J.Allen       BUF    #00338D     9          205.0             0.0
# 894  J.Allen       BUF    #00338D    10          330.0             1.0
# 895  J.Allen       BUF    #00338D    11          197.0             1.0
# 896  J.Allen       BUF    #00338D    12          253.0             2.0
# 897  J.Allen       BUF    #00338D    13          223.0             2.0
# 898  J.Allen       BUF    #00338D    14          147.0             1.0
# 899  J.Allen       BUF    #00338D    15          304.0             4.0
# 900  J.Allen       BUF    #00338D    16          172.0             2.0
#
#      interception  fumble_lost  rushing_yards  rush_touchdown  \
# 886           2.0          0.0           56.0             1.0
# 887           0.0          0.0           10.0             0.0
# 888           0.0          1.0           47.0             0.0
# 889           1.0          0.0           70.0             1.0
# 890           1.0          1.0           42.0             0.0
# 891           0.0          1.0           32.0             0.0
# 892           2.0          0.0           49.0             0.0
# 893           2.0          0.0           86.0             2.0
# 894           2.0          1.0           84.0             0.0
# 895           0.0          0.0            7.0             0.0
# 896           1.0          0.0           78.0             1.0
# 897           0.0          1.0           20.0             0.0
# 898           0.0          0.0           47.0             1.0
# 899           0.0          1.0           77.0             0.0
# 900           2.0          1.0           41.0             1.0
#
#      receiving_yards  touchdown
# 886            297.0        4.0
# 887            317.0        4.0
# 888            400.0        2.0
# 889            213.0        2.0
# 890            424.0        4.0
# 891            329.0        3.0
# 892            218.0        2.0
# 893            205.0        2.0
# 894            330.0        2.0
# 895            197.0        1.0
# 896            253.0        3.0
# 897            223.0        2.0
# 898            147.0        2.0
# 899            304.0        4.0
# 900            172.0        3.0
